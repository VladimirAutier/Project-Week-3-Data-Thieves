# %%
from police_api import PoliceAPI
import pandas as pd

# %%
api = PoliceAPI()

# %%
all_forces = api.get_forces()
all_forces
# Out:
# [<Force> Avon and Somerset Constabulary,
#  <Force> Bedfordshire Police,
#  <Force> Cambridgeshire Constabulary,
#  <Force> Cheshire Constabulary,
#  <Force> City of London Police,
#  <Force> Cleveland Police,
#  <Force> Cumbria Constabulary,
#  <Force> Derbyshire Constabulary,
#  <Force> Devon & Cornwall Police,
#  <Force> Dorset Police,
#  <Force> Durham Constabulary,
#  <Force> Dyfed-Powys Police,
#  <Force> Essex Police,
#  <Force> Gloucestershire Constabulary,
#  <Force> Greater Manchester Police,
#  <Force> Gwent Police,
#  <Force> Hampshire Constabulary,
#  <Force> Hertfordshire Constabulary,
#  <Force> Humberside Police,
#  <Force> Kent Police,
#  <Force> Lancashire Constabulary,
#  <Force> Leicestershire Police,
#  <Force> Lincolnshire Police,
#  <Force> Merseyside Police,
#  <Force> Metropolitan Police Service,
#  <Force> Norfolk Constabulary,
#  <Force> North Wales Police,
#  <Force> North Yorkshire Police,
#  <Force> Northamptonshire Police,
# ...

# %%
london_force = all_forces[24] #FINDING FORCES FOR LONDON
london_force
# Out:
# <Force> Metropolitan Police Service

# %%
london_nei = london_force.neighbourhoods
len(london_nei)
# Out:
# 658

# %%
df_nei = pd.DataFrame({'code': london_nei})
df_nei.head()
# Out:
#                         code
# 0  <Neighbourhood> E05000026
# 1  <Neighbourhood> E05000455
# 2  <Neighbourhood> E05000630
# 3  <Neighbourhood> E05000214
# 4  <Neighbourhood> E05009388

# %%
df_nei['Neighbourhood'] = df_nei.apply(lambda x: x['code'].name, axis=1)
#df_nei.drop(columns=[0],inplace=True)
#df_nei.set_index('Neighbourhood',inplace=True)
#df['Neighbourhood'].crimes[1]
df_nei.head()
# Out:
#                         code Neighbourhood
# 0  <Neighbourhood> E05000026         Abbey
# 1  <Neighbourhood> E05000455         Abbey
# 2  <Neighbourhood> E05000630    Abbey Road
# 3  <Neighbourhood> E05000214    Abbey Wood
# 4  <Neighbourhood> E05009388      Abingdon

# %%
new_crimes=[]
neighb=[]
for i in london_nei[0:2]:
    for j in i.crimes[0:100]:       
        neighb.append(i.name)
        new_crimes.append(j.category)

#print(new_crimes)
#print(neighb)
df_neii=pd.DataFrame(neighb)
df_neii['crimes']=new_crimes
df_neii
#new_list
#london_nei[2].crimes[2]
#df_crime=pd.DataFrame()
#df_crime
# Out:
#          0                                        crimes
# 0    Abbey         <CrimeCategory> Anti-social behaviour
# 1    Abbey         <CrimeCategory> Anti-social behaviour
# 2    Abbey         <CrimeCategory> Anti-social behaviour
# 3    Abbey         <CrimeCategory> Anti-social behaviour
# 4    Abbey         <CrimeCategory> Anti-social behaviour
# ..     ...                                           ...
# 180  Abbey  <CrimeCategory> Violence and sexual offences
# 181  Abbey  <CrimeCategory> Violence and sexual offences
# 182  Abbey  <CrimeCategory> Violence and sexual offences
# 183  Abbey  <CrimeCategory> Violence and sexual offences
# 184  Abbey                   <CrimeCategory> Other crime
#
# [185 rows x 2 columns]

# %%
df_nei['Neighbourhood']=df_nei.apply(lambda x:x['code'].name,axis=1)
#df_nei.drop(columns=[0],inplace=True)
#df_nei.set_index('Neighbourhood',inplace=True)
#df['Neighbourhood'].crimes[1]

# %%
new_crimes=[]
neighb=[]
for i in london_nei[0:2]:
    for j in i.crimes[0:100]:       
        neighb.append(i.name)
        new_crimes.append(j.category)

#print(new_crimes)
#print(neighb)
df_neii=pd.DataFrame(neighb)
df_neii['crimes']=new_crimes
df_neii
#new_list
#london_nei[2].crimes[2]
#df_crime=pd.DataFrame()
#df_crime
# Out:
#               0                                        crimes
# 0         Abbey         <CrimeCategory> Anti-social behaviour
# 1         Abbey         <CrimeCategory> Anti-social behaviour
# 2         Abbey         <CrimeCategory> Anti-social behaviour
# 3         Abbey         <CrimeCategory> Anti-social behaviour
# 4         Abbey         <CrimeCategory> Anti-social behaviour
# ...         ...                                           ...
# 85864  Yiewsley  <CrimeCategory> Violence and sexual offences
# 85865  Yiewsley  <CrimeCategory> Violence and sexual offences
# 85866  Yiewsley  <CrimeCategory> Violence and sexual offences
# 85867  Yiewsley                   <CrimeCategory> Other crime
# 85868  Yiewsley                   <CrimeCategory> Other crime
#
# [85869 rows x 2 columns]

# %%
crime1 = abb.crimes[]
#abb.officers#FINDING OFFCIERS PER LOCATION
crime1.month
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-131-f8de2b077036> in <module>
# ----> 1 crime1 = abb.crimes[1000]
#       2 #abb.officers#FINDING OFFCIERS PER LOCATION
#       3 crime1.month
#
# IndexError: list index out of range

# %%
abb = london_nei[0]#EXAMPLE OF ABBEY
abb.name
df_nei=pd.DataFrame({'code': london_nei})
df_nei
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
neighbourhoods = london_force.neighbourhoods
neighbourhoods_names = [for neighbourhood in neighbourhoods]
# Out:
# [<Neighbourhood> E05000026,
#  <Neighbourhood> E05000455,
#  <Neighbourhood> E05000630,
#  <Neighbourhood> E05000214,
#  <Neighbourhood> E05009388,
#  <Neighbourhood> E05000170,
#  <Neighbourhood> 00AHGF,
#  <Neighbourhood> 00AHGE,
#  <Neighbourhood> E05000250,
#  <Neighbourhood> 00BCFY,
#  <Neighbourhood> E05000266,
#  <Neighbourhood> E05000400,
#  <Neighbourhood> E05000027,
#  <Neighbourhood> E05000085,
#  <Neighbourhood> 00AU01T,
#  <Neighbourhood> E05000251,
#  <Neighbourhood> E05000252,
#  <Neighbourhood> E05000610,
#  <Neighbourhood> 00BCFZ,
#  <Neighbourhood> 00ADGA,
#  <Neighbourhood> E05000516,
#  <Neighbourhood> E05000086,
#  <Neighbourhood> E05000324,
#  <Neighbourhood> 00AU02N,
#  <Neighbourhood> E05000631,
#  <Neighbourhood> E05000475,
#  <Neighbourhood> E05000028,
#  <Neighbourhood> E05000555,
#  <Neighbourhood> E05000556,
#  <Neighbourhood> E05000346,
#  <Neighbourhood> E05000611,
#  <Neighbourhood> E05000437,
#  <Neighbourhood> E05000285,
# ...

# %%
for n in df_nei[0]:
    n.crimes
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-156-c64d775b0304> in <module>
#       1 for n in df_nei[0]:
# ----> 2     n.crimes
#       3
#
# /usr/local/lib/python3.7/site-packages/police_api/neighbourhoods.py in crimes(self)
#     129     def crimes(self):
#     130         if self._crimes is None:
# --> 131             self._crimes = self._get_crimes()
#     132         return self._crimes
#
# /usr/local/lib/python3.7/site-packages/police_api/neighbourhoods.py in _get_crimes(self)
#     105
#     106     def _get_crimes(self):
# --> 107         return self.api.get_crimes_area(self.boundary)
#     108
#     109     @property
#
# /usr/local/lib/python3.7/site-packages/police_api/__init__.py in get_crimes_area(self, points, date, category)
#     117         if date is not None:
#     118             kwargs['date'] = date
# ...

# %%
df_nei
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Neighbourhood'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-f53a3a67f28a> in <module>
# ...
